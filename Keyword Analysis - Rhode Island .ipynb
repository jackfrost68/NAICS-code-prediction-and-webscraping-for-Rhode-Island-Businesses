# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import spacy
import re
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
from selenium import webdriver
from googlesearch import search
import csv

# %%
df = pd.read_csv('/Users/jacobnyamu/Desktop/Spring 2023/Advanced Programming - Python/NTerprisers /Tabrez/output.csv', encoding='latin-1')

# %%
df.head()
# Out:
#                 Company Name Verified
# 0     10 Sachuest Drive, LLC       No
# 1             1120 Park, LLC       No
# 2    115 Williams Street LLC       No
# 3            117 Realty, LLC       No
# 4  11TH MUSE PUBLISHERS, LLC       No

# %%
df2 = df.truncate(before=0, after=21)

# %%
df2.head(22)
# Out:
#                  Company Name Verified
# 0      10 Sachuest Drive, LLC       No
# 1              1120 Park, LLC       No
# 2     115 Williams Street LLC       No
# 3             117 Realty, LLC       No
# 4   11TH MUSE PUBLISHERS, LLC       No
# 5        12 Bluff Avenue, LLC       No
# 6      121 Avondale Road, LLC       No
# 7    151 Boston Neck Road LLC       No
# 8       2 Ocean Lawn Lane LLC       No
# 9            219 Linwood, LLC      Yes
# 10       220 Willett Road LLC       No
# 11                  26.2+ LLC      Yes
# 12            2A Apparel Inc.       No
# 13        32 John Street, LLC       No
# 14             33 Gaspee, LLC       No
# 15                   3305 LLC       No
# 16         332 Canonchet, LLC       No
# 17                  3611, LLC       No
# 18                39 TLS, LLC       No
# 19     4 BALL INVESTMENTS LLC       No
# 20       40 PINE MARITIME LLC       No
# 21           401 Cleaning LLC       No

# %%
# Iterate over each row in the data frame, perform a Google search using the row data, and print the URL of the top result
    
table = []
for index, row in df2.iterrows():
    query = row['entityname']  # Replace 'Search Query' with the name of the column containing the search queries
    result = next(search(query, num_results=1, sleep_interval=0.5), None)
    if result:
        print(f"{index}: '{query}' found at '{result}'")
        table.append([query, result])

    
# print(table)
# Out:
# 0, 1: '10 Sachuest Drive, LLC' found at 'https://www.bizapedia.com/ri/10-sachuest-drive-llc.html'
# 0, 2: '10 Sachuest Drive, LLC' found at 'https://opencorporates.com/companies/us_ri/001662369'
# 0, 3: '10 Sachuest Drive, LLC' found at 'https://www.coldwellbankerhomes.com/ri/middletown/10-sachuest-dr/pid_35213097/'
# 1, 4: '1120 Park, LLC' found at 'https://www.coldwellbankerhomes.com/mi/grand-haven/1120-park-ave/pid_51230788/'
# 2, 5: '115 Williams Street LLC' found at 'https://www.zillow.com/homedetails/115-Williams-St-Providence-RI-02906/65911490_zpid/'
# 3, 6: '117 Realty, LLC' found at 'https://www.realtor.com/realestateagency/63b44c5ffc26d4bfb9b7a121'
# 4, 7: '11TH MUSE PUBLISHERS, LLC' found at 'https://exalexander.com/11th-muse-publishers/'
# 4, 8: '11TH MUSE PUBLISHERS, LLC' found at 'https://opencorporates.com/companies/us_ri/001702472'
# 5, 9: '12 Bluff Avenue, LLC' found at 'https://opencorporates.com/companies/us_ri/001716681'
# 5, 10: '12 Bluff Avenue, LLC' found at 'https://www.dnb.com/business-directory/company-profiles.bluff_avenue_llc.19c2aed86d9855ef8e4a4cb8e668ff30.html'
# 5, 11: '12 Bluff Avenue, LLC' found at 'https://whatsupnewp.com/2020/12/home-on-bluff-avenue-in-westerly-sells-for-11-8-million/'
# 6, 12: '121 Avondale Road, LLC' found at 'https://opencorporates.com/companies/us_ri/001733707'
# 6, 13: '121 Avondale Road, LLC' found at 'https://www.zillow.com/homedetails/121-Avondale-Rd-Westerly-RI-02891/65907775_zpid/'
# 6, 14: '121 Avondale Road, LLC' found at 'https://www.bizapedia.com/ri/121-avondale-road-llc.html'
# 7, 15: '151 Boston Neck Road LLC' found at 'https://opencorporates.com/companies/us_ri/001699344'
# 7, 16: '151 Boston Neck Road LLC' found at 'https://business.sos.ri.gov/CorpWeb/CorpSearch/CorpSummary.aspx?FEIN=001699344'
# 8, 17: '2 Ocean Lawn Lane LLC' found at 'https://opencorporates.com/companies/us_ri/000912431'
# 8, 18: '2 Ocean Lawn Lane LLC' found at 'https://www.redfin.com/RI/Newport/2-Ocean-Lawn-Ln-02840/home/52256930'
# 9, 19: '219 Linwood, LLC' found at 'https://www.zillow.com/homedetails/219-Linwood-Ave-Providence-RI-02907/65965903_zpid/'
# 9, 20: '219 Linwood, LLC' found at 'https://opencorporates.com/companies/us_ri/001724542'
# 10, 21: '220 Willett Road LLC' found at 'https://opencorporates.com/companies/us_ri/001733018'
# 11, 22: '26.2+ LLC' found at 'https://gendekai.com/products/run-26-2-cap'
# 11, 23: '26.2+ LLC' found at 'https://www.ericasara.com/products/boston-course-necklace'
# 12, 24: '2A Apparel Inc.' found at 'https://www.official2a.com/'
# 13, 25: '32 John Street, LLC' found at 'https://opencorporates.com/companies/us_ma/522448105'
# 13, 26: '32 John Street, LLC' found at 'https://www.zillow.com/homedetails/32-John-St-Fall-River-MA-02721/2078995964_zpid/'
# 14, 27: '33 Gaspee, LLC' found at 'https://www.xome.com/realestate/33-gaspee-rd-narragansett-ri-02882-150435114'
# 14, 28: '33 Gaspee, LLC' found at 'https://www.bizapedia.com/ri/33-gaspee-llc.html'
# 15, 29: '3305 LLC' found at 'https://kadhomes.com/listings/3-Battery-Wharf-3305-Boston-MA-02109-103018744'
# 15, 30: '3305 LLC' found at 'http://search.sunbiz.org/Inquiry/corporationsearch/SearchResultDetail?inquirytype=EntityName&directionType=PreviousList&searchNameOrder=LAKEAVE3305%20L110000366540&aggregateId=flal-l11000036654-426aed95-9761-41d8-93ee-c28d5adc42a4&searchTerm=LAKE%20AVENUE%20PARTNERS%2C%20LTD.%2C%20LLLP&listNameOrder=LAKEAUTOPARTS%20J416810'
# 15, 31: '3305 LLC' found at 'https://www.mapquest.com/us/florida/commerce-3305-llc-430796559'
# 16, 32: '332 Canonchet, LLC' found at 'https://opencorporates.com/companies/us_ri/001709386'
# 16, 33: '332 Canonchet, LLC' found at 'https://business.sos.ri.gov/CorpWeb/CorpSearch/CorpSummary.aspx?FEIN=000123862'
# 16, 34: '332 Canonchet, LLC' found at 'https://www.orsonandbrusini.com/_resources/common/userfiles/file/Rockville%20Mill%20LLC%20-%20Bid%20Package.pdf'
# 17, 35: '3611, LLC' found at 'https://opencorporates.com/companies/us_ri/001674514'
# 17, 36: '3611, LLC' found at 'https://www.bloomberg.com/profile/company/1452369D:US'
# 17, 37: '3611, LLC' found at 'https://www.dnb.com/business-directory/company-profiles.sanctuary_clothing_3611_llc.25e2f0f20378553c0ddd3e73e5e38b1c.html'
# 18, 38: '39 TLS, LLC' found at 'https://opencorporates.com/companies/us_ri/001714478'
# 18, 39: '39 TLS, LLC' found at 'https://www.bizapedia.com/ri/39-tls-llc.html'
# 18, 40: '39 TLS, LLC' found at 'https://www.dnb.com/business-directory/company-profiles.tls_llc.85a77f836b860a7254fdeb35d9b03a9e.html'
# 19, 41: '4 BALL INVESTMENTS LLC' found at 'https://opencorporates.com/companies/us_ri/000788008'
# 19, 42: '4 BALL INVESTMENTS LLC' found at 'https://www.bbb.org/us/tx/austin/profile/real-estate-investing/crystal-ball-investments-llc-0825-1000137016'
# 19, 43: '4 BALL INVESTMENTS LLC' found at 'https://www.buzzfile.com/business/Ball-Investments-LLC-419-566-1699'
# 20, 44: '40 PINE MARITIME LLC' found at 'https://opencorporates.com/companies/us_ny/5321518'
# 21, 45: '401 Cleaning LLC' found at 'https://www.care.com/b/l/kaylanni-s-cleaning/pawtucket-ri'
# 21, 46: '401 Cleaning LLC' found at 'https://nextdoor.com/pages/401-cleaning-services-atkinson-nh/'

# %%
urls = pd.DataFrame(table)

# %%
urls.head(20)
# Out:
#                             0  \
# 0      10 Sachuest Drive, LLC
# 1      10 Sachuest Drive, LLC
# 2      10 Sachuest Drive, LLC
# 3              1120 Park, LLC
# 4     115 Williams Street LLC
# 5             117 Realty, LLC
# 6   11TH MUSE PUBLISHERS, LLC
# 7   11TH MUSE PUBLISHERS, LLC
# 8        12 Bluff Avenue, LLC
# 9        12 Bluff Avenue, LLC
# 10       12 Bluff Avenue, LLC
# 11     121 Avondale Road, LLC
# 12     121 Avondale Road, LLC
# 13     121 Avondale Road, LLC
# 14   151 Boston Neck Road LLC
# 15   151 Boston Neck Road LLC
# 16      2 Ocean Lawn Lane LLC
# 17      2 Ocean Lawn Lane LLC
# 18           219 Linwood, LLC
# 19           219 Linwood, LLC
#
#                                                     1
# 0   https://www.bizapedia.com/ri/10-sachuest-drive...
# 1   https://opencorporates.com/companies/us_ri/001...
# 2   https://www.coldwellbankerhomes.com/ri/middlet...
# 3   https://www.coldwellbankerhomes.com/mi/grand-h...
# 4   https://www.zillow.com/homedetails/115-William...
# 5   https://www.realtor.com/realestateagency/63b44...
# 6       https://exalexander.com/11th-muse-publishers/
# 7   https://opencorporates.com/companies/us_ri/001...
# 8   https://opencorporates.com/companies/us_ri/001...
# 9   https://www.dnb.com/business-directory/company...
# 10  https://whatsupnewp.com/2020/12/home-on-bluff-...
# 11  https://opencorporates.com/companies/us_ri/001...
# 12  https://www.zillow.com/homedetails/121-Avondal...
# 13  https://www.bizapedia.com/ri/121-avondale-road...
# 14  https://opencorporates.com/companies/us_ri/001...
# 15  https://business.sos.ri.gov/CorpWeb/CorpSearch...
# 16  https://opencorporates.com/companies/us_ri/000...
# 17  https://www.redfin.com/RI/Newport/2-Ocean-Lawn...
# 18  https://www.zillow.com/homedetails/219-Linwood...
# 19  https://opencorporates.com/companies/us_ri/001...

# %%
urls.set_axis(['Business', 'URL'], axis='columns', inplace=True)
# Out:
# /var/folders/th/00nvfm0d5qg4prl9hls6qx340000gn/T/ipykernel_17991/4196423623.py:1: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   urls.set_axis(['Business', 'URL'], axis='columns', inplace=True)

# %%
urls.head()
# Out:
#                   Business                                                URL
# 0   10 Sachuest Drive, LLC  https://www.bizapedia.com/ri/10-sachuest-drive...
# 1   10 Sachuest Drive, LLC  https://opencorporates.com/companies/us_ri/001...
# 2   10 Sachuest Drive, LLC  https://www.coldwellbankerhomes.com/ri/middlet...
# 3           1120 Park, LLC  https://www.coldwellbankerhomes.com/mi/grand-h...
# 4  115 Williams Street LLC  https://www.zillow.com/homedetails/115-William...

# %%
# Defining keywords related to manufacturing
keywords = [
    "manufacturing", "production", "factory", "industry", "industrial", "machinery",
    "assembly", "fabrication", "plant", "workshop", "process", "machining",
    "milling", "turning", "forging", "casting", "molding", "extrusion",
    "welding", "cutting", "grinding", "lathing", "drilling", "pressing",
    "forming", "stamping", "additive", "3D printing", "injection molding",
    "blow molding", "rotational molding", "thermoforming", "vacuum forming",
    "die casting", "sand casting", "investment casting", "lost-wax casting",
    "cold rolling", "hot rolling", "slitting", "annealing", "heat treatment",
    "sheet metal", "metallurgy", "electroplating", "galvanizing", "coating",
    "powder coating", "anodizing", "painting", "finishing", "quality control",
    "CNC", "computer numerical control", "tooling", "fixtures", "jigs",
    "material handling", "automation", "robotics", "conveyor", "packaging",
    "lean manufacturing", "just-in-time", "six sigma", "continuous improvement",
    "mass production", "batch production", "job production", "assembling",
    "subassembly", "raw material", "work in progress", "finished goods",
    "inventory", "supply chain", "logistics", "procurement", "sourcing",
    "OEM", "original equipment manufacturer", "contract manufacturing",
    "outsourcing", "offshoring", "ISO 9001", "ISO 14001", "quality management",
    "environmental management", "safety", "compliance", "regulation"
]

# %%
# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# Clean the text by removing unnecessary characters
def clean_text(text):
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

# Scrape the website and extract the text
def scrape_website(url):
    try:
        response = requests.get(url)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, "html.parser")
        texts = ' '.join([clean_text(p.text) for p in soup.find_all('p')])

        return texts
    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")
        return ""

# Check if the website is related to manufacturing
def is_manufacturing_website(text, keywords):
    doc = nlp(text.lower())

    for keyword in keywords:
        if keyword in doc.text:
            return True

    return False

# Creating an empty list to store the results
results = [] 
        
for website in urls.URL:
    text = scrape_website(website)
    if is_manufacturing_website(text, keywords):
        result = {"Business": urls.Business, "Manufacturing": True}
    else:
        result = {"Business": urls.Business, "Manufacturing": False}
    results.append(result)

        
urls_verified = pd.DataFrame(results)
# Out:
# Error: 403 Client Error: Forbidden for url: https://www.bizapedia.com/ri/10-sachuest-drive-llc.html
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001662369 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f978afd8d30>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 400 Client Error: Bad Request for url: https://exalexander.com/11th-muse-publishers/
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001702472 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f978ad56770>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001716681 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f978ad575b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 403 Client Error: Forbidden for url: https://www.dnb.com/business-directory/company-profiles.bluff_avenue_llc.19c2aed86d9855ef8e4a4cb8e668ff30.html
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001733707 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f97481321a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 403 Client Error: Forbidden for url: https://www.bizapedia.com/ri/121-avondale-road-llc.html
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001699344 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f9748131c90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/000912431 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f97481293f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 403 Client Error: Forbidden for url: https://www.redfin.com/RI/Newport/2-Ocean-Lawn-Ln-02840/home/52256930
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001724542 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f9748129330>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001733018 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f9748129330>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ma/522448105 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f976a657f70>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 403 Client Error: Forbidden for url: https://www.bizapedia.com/ri/33-gaspee-llc.html
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001709386 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f97788aa950>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001674514 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f978b7bb7c0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 403 Client Error: Forbidden for url: https://www.dnb.com/business-directory/company-profiles.sanctuary_clothing_3611_llc.25e2f0f20378553c0ddd3e73e5e38b1c.html
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001714478 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f97515cc3a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 403 Client Error: Forbidden for url: https://www.bizapedia.com/ri/39-tls-llc.html
# Error: 403 Client Error: Forbidden for url: https://www.dnb.com/business-directory/company-profiles.tls_llc.85a77f836b860a7254fdeb35d9b03a9e.html
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/000788008 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f97515cc430>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 502 Server Error: Bad Gateway for url: https://www.bbb.org/us/tx/austin/profile/real-estate-investing/crystal-ball-investments-llc-0825-1000137016
# Error: 403 Client Error: Forbidden for url: https://www.buzzfile.com/business/Ball-Investments-LLC-419-566-1699
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ny/5321518 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f97515cc040>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %%
# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# Clean the text by removing unnecessary characters
def clean_text(text):
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

# Scrape the website and extract the text
def scrape_website(url):
    try:
        response = requests.get(url)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, "html.parser")
        texts = ' '.join([clean_text(p.text) for p in soup.find_all('p')])

        return texts
    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")
        return ""

# Check if the website is related to manufacturing
def is_manufacturing_website(text, keywords):
    doc = nlp(text.lower())

    for token in doc:
        if token.text in keywords:
            return True

    return False

# Creating an empty list to store the results
results = [] 
final_results = {}
        
for website in urls.URL: 
    text = scrape_website(website)
    if is_manufacturing_website(text, keywords):
        results = {"Business": urls['Business'], "Manufacturing": True}
    else:
        results = {"Business": urls['Business'], "Manufacturing": False}
        
final_results.append(results)
    
urls_verified = pd.DataFrame(final_results)
# Out:
# Error: 403 Client Error: Forbidden for url: https://www.bizapedia.com/ri/10-sachuest-drive-llc.html
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001662369 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f9798238430>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 400 Client Error: Bad Request for url: https://exalexander.com/11th-muse-publishers/
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001702472 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f973b8d50f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001716681 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f973b8d5630>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 403 Client Error: Forbidden for url: https://www.dnb.com/business-directory/company-profiles.bluff_avenue_llc.19c2aed86d9855ef8e4a4cb8e668ff30.html
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001733707 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f97297bbf40>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 403 Client Error: Forbidden for url: https://www.bizapedia.com/ri/121-avondale-road-llc.html
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001699344 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f97297bb040>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/000912431 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f9729736920>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 403 Client Error: Forbidden for url: https://www.redfin.com/RI/Newport/2-Ocean-Lawn-Ln-02840/home/52256930
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001724542 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f9729736830>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001733018 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f9729736830>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ma/522448105 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f978cacfd90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 403 Client Error: Forbidden for url: https://www.bizapedia.com/ri/33-gaspee-llc.html
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001709386 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f9738b73520>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001674514 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f9719c5eb00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 403 Client Error: Forbidden for url: https://www.dnb.com/business-directory/company-profiles.sanctuary_clothing_3611_llc.25e2f0f20378553c0ddd3e73e5e38b1c.html
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/001714478 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f978e0bf070>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 403 Client Error: Forbidden for url: https://www.bizapedia.com/ri/39-tls-llc.html
# Error: 403 Client Error: Forbidden for url: https://www.dnb.com/business-directory/company-profiles.tls_llc.85a77f836b860a7254fdeb35d9b03a9e.html
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ri/000788008 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f978e0be650>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error: 502 Server Error: Bad Gateway for url: https://www.bbb.org/us/tx/austin/profile/real-estate-investing/crystal-ball-investments-llc-0825-1000137016
# Error: 403 Client Error: Forbidden for url: https://www.buzzfile.com/business/Ball-Investments-LLC-419-566-1699
# Error: HTTPSConnectionPool(host='opencorporates.com', port=443): Max retries exceeded with url: /companies/us_ny/5321518 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f978e0bfac0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 44
#      41     else:
#      42         results = {"Business": urls['Business'], "Manufacturing": False}
# ---> 44 final_results.append(results)
#      46 urls_verified = pd.DataFrame(final_results)
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
urls_verified.head(80)
# Out:
#                                              Business  Manufacturing
# 0   0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 1   0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 2   0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 3   0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 4   0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 5   0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 6   0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 7   0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 8   0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 9   0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 10  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 11  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 12  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 13  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 14  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 15  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 16  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 17  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 18  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 19  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 20  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 21  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 22  0        10 Sachuest Drive, LLC
# 1        10 Sa...           True
# 23  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 24  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 25  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 26  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 27  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 28  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 29  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 30  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 31  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 32  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 33  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 34  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 35  0        10 Sachuest Drive, LLC
# 1        10 Sa...           True
# 36  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 37  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 38  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 39  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 40  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 41  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 42  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 43  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 44  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
# 45  0        10 Sachuest Drive, LLC
# 1        10 Sa...          False
